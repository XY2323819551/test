# %%
# coding=utf-8
import numpy as np
from gensim import corpora, models, similarities
import keras
import keras.backend as K
from keras.engine.topology import Layer
# Out:
# Using TensorFlow backend.

# %%
class NegativeLayer(Layer):
    def __init__(self, nb_negative,M,M_num, **kwargs):


        self.nb_negative = nb_negative
        self.M = M
        self.M_num = M_num
        super(NegativeLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        super(NegativeLayer, self).build(input_shape)


    def call(self, x, mask=None):

        batch = 0
        if str(x.shape[0]).isdigit() == False:
            batch = 4
        else:
            batch = x.shape[0]
        #负采样
        final_output = np.array([[M[i] for i in j]for j in np.random.randint(0, self.M_num+1, size=(batch, self.nb_negative))])
        #变成tensor格式
        final_output = K.tensorflow_backend._to_tensor(final_output,dtype=np.int32)
        return final_output
    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.nb_negative)
if __name__ == '__main__':
    text = [["我","今天","打","篮球"],
            ["我","今天","打","足球"],
            ["我","今天","打","羽毛球"],
            ["我","今天","打","网球"],
            ["我","今天","打","排球"],
            ["我","今天","打","气球"],
            ["我","今天","打","游戏"],
            ["我","今天","打","冰球"],
            ["我","今天","打","人"],
            ["我","今天","打","台球"],
            ["我","今天","打","桌球"],
            ["我","今天","打","水"],
            ["我","今天","打","篮球"],
            ["我","今天","打","足球"],
            ["我","今天","打","羽毛球"],
            ["我","今天","打","网球"],
            ["我","今天","打","排球"],
            ["我","今天","打","气球"],
            ]
    #使用gensim生成词典
    dictionary = corpora.Dictionary(text,prune_at=2000000)
    
    #打印词典中的词
    for key in dictionary.iterkeys():
        print(key,dictionary.get(key),dictionary.dfs[key])
    #保存词典
    dictionary.save_as_text('word_dict.dict',  sort_by_word=True)
    #加载词典
    dictionary = dictionary.load_from_text('word_dict.dict')
    
    L = {}
    #计算出词出现的总数，dictionary.dfs{单词id，在多少文档中出现}
    allword_num = np.sum(list(dictionary.dfs.values()))
    print(allword_num)
    #72
    
    #构造负采样dict
    #进行归一化,然后按照0-1排列,然后再使用M个均等值来评分0-1，方便对应词的id
    sum = 0
    M = {}
    M_num = 1000
    for id,num in dictionary.dfs.items():
        #向上取整
        left = int(np.ceil(sum/(1/M_num)))
        sum = sum + num/allword_num
        L[id] = sum
        #向下取整
        right = int(sum/(1/M_num))
        print(id,left,right)
#         11 0 13
#         0 14 263
#         10 264 277
#         12 278 291
#         1 292 541
#         2 542 791
#         7 792 819
#         13 820 833
#         8 834 861
#         14 862 875
#         9 875 888
#         3 889 916
#         6 917 944
#         5 945 972
#         4 973 1000
        for i in range(left,right+1):
            M[i] = id
    print(L)
    #{11: 0.013888888888888888, 0: 0.25, 10: 0.013888888888888888, 12: 0.013888888888888888, 1: 0.25, 2: 0.25, 7: 0.027777777777777776, 13: 0.013888888888888888, 8: 0.027777777777777776, 14: 0.013888888888888888, 9: 0.013888888888888888, 3: 0.027777777777777776, 6: 0.027777777777777776, 5: 0.027777777777777776, 4: 0.027777777777777776}
        
    #词语个数
    word_num = len(dictionary.keys())
    #使用多少编文章生成每个batch数据
    sentence_batch_size = 1
    #滑动窗口
    window = 3
    def data_generator(): #训练数据生成器
        while True:
            x,y = [],[]
            _ = 0
            for sentence in text:
                #使用word_num的值作为padding
                sentence = [word_num]*window + [dictionary.token2id[w] for w in sentence if w in dictionary.token2id] + [word_num]*window
                for i in range(window, len(sentence)-window):
                    x.append(sentence[i-window:i]+sentence[i+1:i+1+window])
                    #因为使用的loss函数为sparse_categorical_crossentropy，所以不用one-hot
                    y.append([sentence[i]])
                _ += 1
                if _ == sentence_batch_size:
                    x,y = np.array(x),np.array(y)
                    #因为正例为输出层第一个神经元，所以这里都使用0标签，也是因为loss函数为sparse_categorical_crossentropy
                    z = np.zeros((len(x), 1))
                    print("输入的数据 :",x.shape)
                    print("对应的标签 :",y.shape)
                    print("对应的标签 2:",z.shape)
                    yield [x,y],z
                    x,y = [],[]
                    _ = 0
        
    from keras.models import Sequential
    from keras.layers import Dense, Activation,Embedding,Reshape,Flatten,Input,Embedding,Lambda

    from keras.models import Model
    #词向量维度
    word_size = 100
    #负样本个数
    nb_negative = 16
    
    input_words = Input(shape=(window*2,), dtype='int32')
    input_vecs = Embedding(word_num+1, word_size, name='word2vec')(input_words)
    input_vecs_sum = Lambda(lambda x: K.sum(x, axis=1))(input_vecs) #CBOW模型，直接将上下文词向量求和
    
    #构造随机负样本，与目标组成抽样
    target_word = Input(shape=(1,), dtype='int32')
    negatives = NegativeLayer(16,M,M_num)(target_word)
    samples = Lambda(lambda x: K.concatenate(x))([target_word,negatives]) #构造抽样，负样本随机抽。负样本也可能抽到正样本，但概率小。
    
    #使用Embedding层代替dense主要原因是只更新正例和负例相对应的输出层神经元的权重，这样可以大量减少内存占用和计算量
    softmax_weights = Embedding(word_num+1, word_size, name='W')(samples)
    softmax_biases = Embedding(word_num+1, 1, name='b')(samples)
    softmax = Lambda(lambda x: 
                        K.softmax((K.batch_dot(x[0], K.expand_dims(x[1],2))+x[2])[:,:,0])
                    )([softmax_weights,input_vecs_sum,softmax_biases]) #用Embedding层存参数，用K后端实现矩阵乘法，以此复现Dense层的功能
    
    #留意到，我们构造抽样时，把目标放在了第一位，也就是说，softmax的目标id总是0，这可以从data_generator中的z变量的写法可以看出
    
    model = Model(inputs=[input_words,target_word], outputs=softmax)
    model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    

     
    model.summary()
    model.fit_generator(data_generator(),steps_per_epoch =np.ceil(dictionary.num_docs/sentence_batch_size),epochs=100,max_queue_size=1,workers=1)
#     #保存模型
    model.save_weights("DNNword-vec2.h5")
#     #加载模型
    model.load_weights("DNNword-vec2.h5",by_name=True)
#     
    #获取embeding的权重，也就是词向量
    embeddings = model.get_weights()[0]
    #向量标准化
    normalized_embeddings = embeddings / (embeddings**2).sum(axis=1).reshape((-1,1))**0.5
    dictionary.id2token = {j:i for i,j in dictionary.token2id.items()}
    #获取前面最相似的15个词语
    def most_similar(w,dictionary):
        v = normalized_embeddings[dictionary.token2id[w]]
        #向量标准化之后分母就是1，所以直接相乘就好
        sims = np.dot(normalized_embeddings, v)
        sort = sims.argsort()[::-1]
        sort = sort[sort > 0]
        return [(dictionary.id2token[i],sims[i]) for i in sort[:15] if i in dictionary.id2token]
     
    for sim in most_similar(u'网球',dictionary):
        print(sim[0],sim[1])
# 网球 0.99999994
# 羽毛球 0.9787248
# 篮球 0.978495
# 排球 0.9773369
# 人 0.9761201
# 水 0.9760275
# 气球 0.9753146
# 桌球 0.9731983
# 冰球 0.97278094
# 游戏 0.9711289
# 足球 0.9660615
# 台球 0.96072686
# 我 -0.3409065
# 打 -0.42166257
# Out:
# 0 今天 18
# 1 我 18
# 2 打 18
# 3 篮球 2
# 4 足球 2
# 5 羽毛球 2
# 6 网球 2
# 7 排球 2
# 8 气球 2
# 9 游戏 1
# 10 冰球 1
# 11 人 1
# 12 台球 1
# 13 桌球 1
# 14 水 1
# 72
# 11 0 13
# 0 14 263
# 10 264 277
# 12 278 291
# 1 292 541
# 2 542 791
# 7 792 819
# 13 820 833
# 8 834 861
# 14 862 875
# 9 875 888
# 3 889 916
# 6 917 944
# 5 945 972
# 4 973 1000
# {11: 0.013888888888888888, 0: 0.2638888888888889, 10: 0.2777777777777778, 12: 0.2916666666666667, 1: 0.5416666666666667, 2: 0.7916666666666667, 7: 0.8194444444444445, 13: 0.8333333333333334, 8: 0.8611111111111112, 14: 0.875, 9: 0.8888888888888888, 3: 0.9166666666666666, 6: 0.9444444444444444, 5: 0.9722222222222222, 4: 1.0}
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 1)            0
# __________________________________________________________________________________________________
# negative_layer_1 (NegativeLayer (None, 16)           0           input_2[0][0]
# __________________________________________________________________________________________________
# input_1 (InputLayer)            (None, 6)            0
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 17)           0           input_2[0][0]
#                                                                  negative_layer_1[0][0]
# __________________________________________________________________________________________________
# word2vec (Embedding)            (None, 6, 100)       1600        input_1[0][0]
# __________________________________________________________________________________________________
# W (Embedding)                   (None, 17, 100)      1600        lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 100)          0           word2vec[0][0]
# __________________________________________________________________________________________________
# b (Embedding)                   (None, 17, 1)        16          lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 17)           0           W[0][0]
#                                                                  lambda_1[0][0]
#                                                                  b[0][0]
# ==================================================================================================
# Total params: 3,216
# Trainable params: 3,216
# Non-trainable params: 0
# __________________________________________________________________________________________________
# C:\Users\dell\AppData\Roaming\Python\Python37\site-packages\tensorflow\python\framework\indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 1s - loss: 2.8373 - accuracy: 0.0000e+00输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 (4, 6)
# 18/18 [==============================] - 0s 6ms/step - loss: 2.8052 - accuracy: 0.2361
# (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 2/100
# 输入的数据 : (4, 6)
#  1/18 [>.............................] - ETA: 0s - loss: 2.7473 - accuracy: 0.2500对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# (4, 1)18/18 [==============================] - 0s 2ms/step - loss: 2.7288 - accuracy: 0.2500
#
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 3/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 2.6552 - accuracy: 0.2500
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 2.6303 - accuracy: 0.2500
# Epoch 4/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 2.5255 - accuracy: 0.2500输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 2.4861 - accuracy: 0.3472
# Epoch 5/100
#  1/18 [>.............................] - ETA: 0s - loss: 2.3455 - accuracy: 0.7500(4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 2.2961 - accuracy: 0.7639
# (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 6/100
#  1/18 [>.............................] - ETA: 0s - loss: 2.1291 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 2.0891 - accuracy: 0.8611
#
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 7/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.9145 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 (4, 6)
# 对应的标签 : (4, 1)
# 18/18 [==============================]对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
#  - 0s 2ms/step - loss: 1.9025 - accuracy: 0.8750
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 8/100
#  1/18 [>.............................](4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: - ETA: 0s - loss: 1.7299 - accuracy: 1.0000 (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.7536 - accuracy: 0.8889
# Epoch 9/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.5788 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.6385 - accuracy: 0.8889
#
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 10/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.4557 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 (4, 6)
# 对应的标签 : (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.5497 - accuracy: 0.8333
# (4, 1)
# Epoch 11/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.3591 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.4824 - accuracy: 0.8889
# Epoch 12/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.2873 - accuracy: 0.7500 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2(4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.4323 - accuracy: 0.8611
# Epoch 13/100
#  (4, 6)
# 对应的标签 : (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.2361 - accuracy: 1.0000对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.3952 - accuracy: 0.9028
# Epoch 14/100
# 输入的数据 : (4, 6)
#  1/18 [>.............................] - ETA: 0s - loss: 1.1999 - accuracy: 1.0000(4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.3674 - accuracy: 0.9028
# Epoch 15/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.1740 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4,
# 对应的标签 : (4, 1)
# 对应的标签 2:18/18 [==============================] - 0s 2ms/step - loss: 1.3461 - accuracy: 0.8750
#  (4, 1)
# Epoch 16/100
# (4, 6):
# 对应的标签 : 1/18 [>.............................] - ETA: 0s - loss: 1.1549 - accuracy: 1.0000 (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.3294 - accuracy: 0.8750
# Epoch 17/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.1404 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 (4, 6)
# 对应的标签 : (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.3161 - accuracy: 0.9028
# 对应的标签 2: (4, 1)
# Epoch 18/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.1292 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4,
# 18/18 [==============================] - 0s 2ms/step - loss: 1.3054 - accuracy: 0.8472
# Epoch 19/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.1202 - accuracy: 0.7500 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2(4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2967 - accuracy: 0.8611
# Epoch 20/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.1130 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2894 - accuracy: 0.8889
# Epoch 21/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.1070 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2834 - accuracy: 0.8750
# Epoch 22/100
# 输入的数据 : (4, 6)
#  1/18 [>.............................] - ETA: 0s - loss: 1.1021 - accuracy: 1.0000对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4,
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2782 - accuracy: 0.8889
# Epoch 23/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0979 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2739 - accuracy: 0.8750
# Epoch 24/100
# 输入的数据 : (4, 6)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0944 - accuracy: 1.0000对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2702 - accuracy: 0.8611
# Epoch 25/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0914 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4,
# 输入的数据 : (4, 6)
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2669 - accuracy: 0.8889
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 26/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0888 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2641 - accuracy: 0.8333
# Epoch 27/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0865 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2617 - accuracy: 0.8333
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 28/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0845 - accuracy: 1.0000(4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2595 - accuracy: 0.8333
# (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 29/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0828 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2576 - accuracy: 0.8611
# Epoch 30/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0812 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2(4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2559 - accuracy: 0.8472
# Epoch 31/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0798 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 (4, 6)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2544 - accuracy: 0.8056
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 32/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0786 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  (4, 6)18/18 [==============================] - 0s 2ms/step - loss: 1.2530 - accuracy: 0.8611
#
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 33/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0775 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2517 - accuracy: 0.8472
# Epoch 34/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0765 - accuracy: 1.0000对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2506 - accuracy: 0.8889
# Epoch 35/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0756 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 :18/18 [==============================] - 0s 2ms/step - loss: 1.2496 - accuracy: 0.8472
#  (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 36/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0748 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4,
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2487 - accuracy: 0.8889
# Epoch 37/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0741 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2478 - accuracy: 0.8889
# Epoch 38/100
# 输入的数据 : (4, 6)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0734 - accuracy: 0.7500对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2471 - accuracy: 0.8611
# Epoch 39/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0728 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2464 - accuracy: 0.8472
# Epoch 40/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0722 - accuracy: 0.7500输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2457 - accuracy: 0.8194
# Epoch 41/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0717 - accuracy: 1.0000(4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2451 - accuracy: 0.8472
# Epoch 42/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0712 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2445 - accuracy: 0.8889
# Epoch 43/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0707 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2440 - accuracy: 0.8472
# Epoch 44/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0703 - accuracy: 1.0000对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2435 - accuracy: 0.8472
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 45/100
# 输入的数据 :  1/18 [>.............................](4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  - ETA: 0s - loss: 1.0699 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# ...
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2362 - accuracy: 0.7778
# Epoch 86/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0641 - accuracy: 0.7500(4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2362 - accuracy: 0.8611
#
# 对应的标签 2: (4, 1)
# Epoch 87/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0641 - accuracy: 0.7500输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2361 - accuracy: 0.8472
# Epoch 88/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0640 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2360 - accuracy: 0.8472
# Epoch 89/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0640 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2360 - accuracy: 0.8611
#  (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 90/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0639 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2359 - accuracy: 0.8889
#
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 91/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0639 - accuracy: 0.7500输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2359 - accuracy: 0.8333
# Epoch 92/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0639 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 1ms/step - loss: 1.2358 - accuracy: 0.8889
# Epoch 93/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0638 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2358 - accuracy: 0.8611
#
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# Epoch 94/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0638 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2357 - accuracy: 0.8472
# Epoch 95/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0638 - accuracy: 0.7500输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2357 - accuracy: 0.8333
# Epoch 96/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0637 - accuracy: 0.7500(4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2357 - accuracy: 0.8333
# 对应的标签 2: (4, 1)
# Epoch 97/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0637 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2356 - accuracy: 0.8472
# Epoch 98/100
#  1/18 [>.............................] - ETA: 0s - loss: 1.0637 - accuracy: 1.0000 (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2356 - accuracy: 0.8194
# Epoch 99/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0636 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2355 - accuracy: 0.8472
# Epoch 100/100
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
#  1/18 [>.............................] - ETA: 0s - loss: 1.0636 - accuracy: 1.0000输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 对应的标签 : (4, 1)
# 对应的标签 2: (4, 1)
# 输入的数据 : (4, 6)
# 18/18 [==============================] - 0s 2ms/step - loss: 1.2355 - accuracy: 0.8472
#
# 对应的标签 2: (4, 1)
# 网球 1.0000002
# 足球 0.97214234
# 气球 0.9720458
# 排球 0.9717551
# 羽毛球 0.9714309
# 篮球 0.9699856
# 游戏 0.9692031
# 人 0.9634192
# 台球 0.9555415
# 水 0.95459664
# 桌球 0.95376074
# 冰球 0.95091724
# 打 -0.18016617
# 我 -0.46530703
